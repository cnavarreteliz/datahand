# %%
import pandas as pd
import os

os.chdir("../")

from datahand import read_wos

# %%
df = read_wos("tests/data/data_wos.txt")
df.head()
# Out:
#                                    ﻿F   VR PT  \
# 0  Clarivate Analytics Web of Science  1.0  J
# 1                                 NaN  NaN  J
# 2                                 NaN  NaN  J
# 3                                 NaN  NaN  J
# 4                                 NaN  NaN  J
#
#                                               AU  \
# 0                                   [Ruderer, S]
# 1                    [Ivanova, A, Almendras, JJ]
# 2                [Cortes-Morales, S, Morales, C]
# 3                                   [Salazar, F]
# 4  [Pizarro-Mena, RA, Duran-Aguero, S, Silva, A]
#
#                                                   AF  \
# 0                                 [Ruderer, Stephan]
# 1          [Ivanova, Anna, Jocelin Almendras, Jorge]
# 2          [Cortes-Morales, Susana, Morales, Camilo]
# 3                                  [Salazar, Flavio]
# 4  [Andres Pizarro-Mena, Rafael, Duran-Aguero, Sa...
#
#                                                   TI  \
# ...
